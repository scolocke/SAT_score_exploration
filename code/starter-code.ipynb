# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# Problem Statement:
# We believe that the current usage of standardized tests, such as the SAT, has inherent bias based on demographics, and we examine the extent of this possible bias.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# Lawsuits have been brought against university admissions on the grounds that standardized tests are biased, potentially on an economic or racial basis. While the counter to it is it is the only reliable way to adequately judge students from schools with potentially different standards. ([*source*](https://www.forbes.com/sites/kimelsesser/2019/12/11/lawsuit-claims-sat-and-act-are-biased-heres-what-research-says/))

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# 2017-2019 SAT scores by state

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# I look to use a more in depth summary using data from the SAT annual report from their suite of assesments to better separate the data based off of different groups. Since the included data sets have participation calculated, the two will be used in tandem to compliment each other.
#
# Outside datasets:
#  - 2017 ([*source*](https://research.collegeboard.org/programs/sat/data/2017-sat-suite-annual-report))
#  - 2018 ([*source*](https://research.collegeboard.org/programs/sat/data/2018-sat-suite-annual-report))
#  - 2019 ([*source*](https://research.collegeboard.org/programs/sat/data/2019-sat-suite-annual-report))

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
#need math for nan so things don't break
import math

def calc_mean(nums):
    nums_nonan = [num for num in nums if not math.isnan(num)]
    return sum(nums_nonan)/len(nums_nonan)

calc_mean([1,2,3])
# Out:
# 2.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
#Standard deviation, but I use n-1 to match tradiational and pandas calculation
def calc_std(nums):
    nums_nonan = [num for num in nums if not math.isnan(num)]
    mean_nums = calc_mean(nums_nonan)
    return (sum([(num - mean_nums)**2 for num in nums_nonan]) / (len(nums_nonan)-1))**0.5
calc_std([1,2,3])
# Out:
# 1.0

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code: check if string, return percentage, if not just return
def return_perc(perc):
    try:
        return float(perc[:-1])/100
    except:
        return perc
return_perc('30.5%')
# Out:
# 0.305

# %%
#remove commas from big numbers
def fix_num(num):
    try:
        return float(num.replace(',',''))
    except:
        return float(num)

# %%
#standardize state names
def rename_states(state):
    if state != 'district of columbia':
        return state.replace(' ','-')
    else:
        return 'district-columbia'

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import tabula
import requests
import seaborn as sns
import matplotlib.cm as cm
import matplotlib.ticker as mtick

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Code:
# set the different categories 
categories = ['total','asian','white','latino','pacific','native','black','multi','no_race','female','male']

#read in the yearly csv
sat2017 = pd.read_csv('../data/sat_2017.csv')
#print(sat2017.head())
sat2018 = pd.read_csv('../data/sat_2018.csv')
#print(sat2018.head())
sat2019 = pd.read_csv('../data/sat_2019.csv')
#print(sat2019.head())

# %%
#check for null values
print(sat2017.isnull().sum())
print(sat2018.isnull().sum())
print(sat2019.isnull().sum())
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
#look at size
print(sat2017.shape)
print(sat2018.shape)
#two more entries in sat2019, seen in describe count as well
print(sat2019.shape)
# Out:
# (51, 5)
# (51, 5)
# (53, 5)

# %%
#find out puerto rico and virgin islands are in 2019, drop them
extra_states = []
for state in sat2019['State']:
    if state not in sat2018['State'].values:
        extra_states.append(state)

for state in extra_states:
    sat2019 = sat2019[sat2019['State'] != state]
print(sat2019.shape)
# Out:
# (51, 5)

# %%
#remapping different column names to be snake case, and informative

fixednames = {'Evidence-Based Reading and Writing': 'reading_writing', 
              'Math': 'math','Total':'total','EBRW':'reading_writing',
              'Participation Rate':'participation', 'Participation':'participation',
              'State':'state'}
sat2017.rename(columns=fixednames,inplace=True)
#https://stackoverflow.com/questions/39512002/convert-whole-dataframe-from-lower-case-to-upper-case-with-pandas
#make lowercase
sat2017 = sat2017.applymap(lambda s:s.lower() if type(s) == str else s)
sat2018 = sat2018.applymap(lambda s:s.lower() if type(s) == str else s)
sat2019 = sat2019.applymap(lambda s:s.lower() if type(s) == str else s)

#Actually fixt the names
sat2018.rename(columns=fixednames,inplace=True)
sat2019.rename(columns=fixednames,inplace=True)
print(sat2017.dtypes)
# Out:
# state              object
# participation      object
# reading_writing     int64
# math                int64
# total               int64
# dtype: object

# %%
#standardize the state names
sat2017['state'] = sat2017['state'].map(rename_states)
sat2018['state'] = sat2018['state'].map(rename_states)
sat2019['state'] = sat2019['state'].map(rename_states)

print(sat2017['state'])
# Out:
# 0               alabama
# 1                alaska
# 2               arizona
# 3              arkansas
# 4            california
# 5              colorado
# 6           connecticut
# 7              delaware
# 8     district-columbia
# 9               florida
# 10              georgia
# 11               hawaii
# 12                idaho
# 13             illinois
# 14              indiana
# 15                 iowa
# 16               kansas
# 17             kentucky
# 18            louisiana
# 19                maine
# 20             maryland
# 21        massachusetts
# 22             michigan
# 23            minnesota
# 24          mississippi
# 25             missouri
# 26              montana
# 27             nebraska
# 28               nevada
# 29        new-hampshire
# 30           new-jersey
# 31           new-mexico
# 32             new-york
# 33       north-carolina
# 34         north-dakota
# 35                 ohio
# 36             oklahoma
# 37               oregon
# ...

# %%
#make the former string now a float

# %%
sat2017['participation']=sat2017['participation'].map(return_perc).astype(float)
sat2018['participation']=sat2018['participation'].map(return_perc).astype(float)
sat2019['participation']=sat2019['participation'].map(return_perc).astype(float)

sat2019.head(10)
# Out:
#                state  participation  reading_writing  math  total
# 0            alabama           0.07              583   560   1143
# 1             alaska           0.41              556   541   1097
# 2            arizona           0.31              569   565   1134
# 3           arkansas           0.06              582   559   1141
# 4         california           0.63              534   531   1065
# 5           colorado           1.00              518   506   1024
# 6        connecticut           1.00              529   516   1046
# 7           delaware           1.00              499   486    985
# 8  district-columbia           0.94              495   480    975
# 9            florida           1.00              516   483    999

# %%
# add year to the information

# %%
sat2017['year'] = [2017 for i in range(sat2017.shape[0])]
sat2018['year'] = [2018 for i in range(sat2018.shape[0])]
sat2019['year'] = [2019 for i in range(sat2019.shape[0])]

# %%
#combine the datasets

# %%
satall = pd.concat([sat2017,sat2018,sat2019])
satall.shape
satall[(satall['year'] == 2019) & (satall['state'] == 'alabama')]
# Out:
#      state  participation  reading_writing  math  total  year
# 0  alabama           0.07              583   560   1143  2019

# %% [markdown]
# make a state list for lookup purposes

# %%
state_list = [state.replace(' ','-') if state != 'district of columbia' else 'district-columbia' for state in sat2017['state'].values]

# %%
# sat2017['year'] = [2017 for i in range(sat2017.shape[0])]
# sat2018['year'] = [2018 for i in range(sat2018.shape[0])]
# sat2019['year'] = [2019 for i in range(sat2019.shape[0])]

# satall = pd.concat([sat2017,sat2018,sat2019])

# satall

# #census[(census['race'] == 1) & ((census['age'] == 18) | (census['age'] == 17))]

# %%
#Function for cleaning the data arrays

# %%
#Function for cleaning the data arrays. All input pdfs match mostly the same form.
#No gender category occasionally missing, extra shape test

def clean_aar(test_aar,year,state,participation,aver):
    #drop weird cells from importing pdf
    if test_aar.shape[0] == 18:
        test_aar = test_aar.drop(17)        
    test_aar = test_aar.drop([0,2,3,4,13,14])
    #rename columns
    test_aar.columns = ['categories','test_takers','total_mean','erw_mean','math_mean','met_both','benchmarks','met_neither']
    #remove %
    test_aar['test_takers'] = [string.split()[0] if type(string) == str else string  for string in test_aar['test_takers']]
    test_aar['erw_met'] = [return_perc(string.split()[0]) if type(string) == str else string for string in test_aar['benchmarks']]
    test_aar['math_met'] = [return_perc(string.split()[1]) if type(string) == str else string for string in test_aar['benchmarks']]
    #unnecessary
    test_aar = test_aar.drop(columns = ['benchmarks'])
    #fix numbers, percentage, types, etc
    test_aar['met_both'] = test_aar['met_both'].map(return_perc)
    test_aar['met_neither'] = test_aar['met_neither'].map(return_perc)
    test_aar['test_takers'] = test_aar['test_takers'].map(fix_num)
    test_aar['total_mean'] = test_aar['total_mean'].astype(float)
    test_aar['erw_mean'] = test_aar['erw_mean'].astype(float)
    test_aar['math_mean'] = test_aar['math_mean'].astype(float)
    #rename the different categories
    test_aar['categories'] = ['total','native','asian','black','latino','pacific','white','multi','no_race','female','male']
    #add info from other dataset, there is a lot overlap
    test_aar['year'] = year
    test_aar['state'] = state
    test_aar['participation'] = participation
    #add relative to average
    test_aar['diff_to_ave'] = test_aar['total_mean'] - float(aver)
    
    return test_aar

# %%
#idea from https://medium.com/level-1/pdf-data-mining-a-lazy-meditation-a4e3a26a9250
import tabula

aar_list = []
# Read pdf into a list of DataFrame
#Comments at line beginning are to prevent redownloading the pdfs. 

for year in range(2017,2020):
    #load pdf
#     url = f'https://reports.collegeboard.org/pdf/{year}-total-group-sat-suite-assessments-annual-report.pdf'
#
    #set base total variables, did not recalculate nationwide participation
    participation = np.nan
    state = 'all'
    #base naming convention
    data_name = f'{year}_total-group_sat_aar'
    #retrieve data
#     r = requests.get(url, allow_redirects=True)
    #write data
#     open(f'../data/state_sat/{data_name}.pdf','wb').write(r.content)
    #read pdf
    df = tabula.read_pdf_with_template(f"../data/state_sat/{data_name}.pdf","../data/state_sat/suite-of-assessments-annual-report.tabula-template-3.json")[0]
    #total average
    aver = df['Unnamed: 0'][1]
    #run cleaning
    df = clean_aar(df,year,state,participation,aver)
    #add to list
    aar_list.append(df)

    for state in state_list:
        #same as above, just for states instead of total
#         url = f'https://reports.collegeboard.org/pdf/{year}-{state}-sat-suite-assessments-annual-report.pdf'
        participation = satall[(satall['state'] == state) & (satall['year'] == year)]['participation'].values[0]
        aver = satall[(satall['state'] == state) & (satall['year'] == year)]['total'].values[0]
        data_name = f'{year}_sat_{state}_aar'
#         r = requests.get(url, allow_redirects=True)
#         open(f'../data/state_sat/{data_name}.pdf','wb').write(r.content)
        df = tabula.read_pdf_with_template(f"../data/state_sat/{data_name}.pdf","../data/state_sat/suite-of-assessments-annual-report.tabula-template.json")[0]
        aver = df['Unnamed: 0'][1]
        df = clean_aar(df,year,state,participation,aver)
        aar_list.append(df)

    
df
# Out:
#    categories  test_takers  total_mean  erw_mean  math_mean  met_both  \
# 1       total        156.0      1238.0     623.0      615.0      0.75
# 5      native          0.0         NaN       NaN        NaN       NaN
# 6       asian          9.0         NaN       NaN        NaN       NaN
# 7       black          1.0         NaN       NaN        NaN       NaN
# 8      latino         12.0      1078.0     546.0      533.0      0.25
# 9     pacific          0.0         NaN       NaN        NaN       NaN
# 10      white        121.0      1254.0     632.0      621.0      0.82
# 11      multi         10.0      1195.0     609.0      586.0      0.60
# 12    no_race          3.0         NaN       NaN        NaN       NaN
# 15     female         94.0      1228.0     624.0      603.0      0.72
# 16       male         62.0      1253.0     621.0      632.0      0.79
#
#     met_neither  erw_met  math_met  year    state  participation  diff_to_ave
# ...

# %%
#combining all of the dataframes

df_all = pd.concat(aar_list)
df_all = df_all.reset_index(drop=True)
df_all
# Out:
#      categories  test_takers  total_mean  erw_mean  math_mean  met_both  \
# 0         total    1715481.0      1060.0     533.0      527.0      0.46
# 1        native       7782.0       963.0     486.0      477.0      0.27
# 2         asian     158031.0      1181.0     569.0      612.0      0.70
# 3         black     225860.0       941.0     479.0      462.0      0.20
# 4        latino     408067.0       990.0     500.0      489.0      0.31
# ...         ...          ...         ...       ...        ...       ...
# 1711      white        121.0      1254.0     632.0      621.0      0.82
# 1712      multi         10.0      1195.0     609.0      586.0      0.60
# 1713    no_race          3.0         NaN       NaN        NaN       NaN
# 1714     female         94.0      1228.0     624.0      603.0      0.72
# 1715       male         62.0      1253.0     621.0      632.0      0.79
#
#       met_neither  erw_met  math_met  year    state  participation  \
# ...

# %%
#check data types of final df
df_all.dtypes
# Out:
# categories        object
# test_takers      float64
# total_mean       float64
# erw_mean         float64
# math_mean        float64
# met_both         float64
# met_neither      float64
# erw_met          float64
# math_met         float64
# year               int64
# state             object
# participation    float64
# diff_to_ave      float64
# dtype: object

# %%
#save the dataframe to csv
df_all.to_csv('../data/allsat.csv')

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# ### My Data Dictionary
#
# Although most figures could be ints, saved as floats due to easier handling of no data from not enough students taking the test.
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |categories|object|SAT|Different demographic categories,broken into ethnicity and gender for a given state and year|
# |test_takers|float|SAT|Number of test takers for the for the specific category|
# |total_mean|float|SAT|Average combined score for math and evidence based reading and writing (max score 1600, min score 400)|
# |erw_mean|float|SAT|Average score on the evidence based reading and writing section (200-800)|
# |math_mean|float|SAT|Average score on the math section (200-800)|
# |met_both|float|SAT|Proportion of students that meet both benchmarks for math and evidence based reading and writing. Benchmark corresponds to score assigned to likely achieve a score of 75% or greater in the corresponding freshman courses|
# |met_neither|float|SAT|Proportion of students that did not meet either benchmarks for math and evidence based reading and writing. Benchmark corresponds to score assigned to likely achieve a score of 75% or greater in the corresponding freshman courses|
# |erw_met|float|SAT|Proportion of students that meet benchmark for evidence based reading and writing. Benchmark corresponds to score assigned to likely achieve a score of 75% or greater in the corresponding freshman courses|
# |math_met|float|SAT|Proportion of students that meet benchmark for math. Benchmark corresponds to score assigned to likely achieve a score of 75% or greater in the corresponding freshman courses|
# |year|int|SAT|Year that the test results were recorded.|
# |state|object|SAT|State for which the data set corresponds. "all" refers to the data corresponding to all of the US|
# |participation|float|SAT|Proportion of the student popualtion for the given state that partook in the SAT|
# |diff_to_ave|float|SAT|Difference between category and total for the correspoding state and year.|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# Summary Statistics, showing the total category

# %%
df_states = df_all[df_all['state'] != 'all']
df_states[df_states['categories'] == 'total'].describe()
# Out:
#          test_takers   total_mean    erw_mean   math_mean    met_both  \
# count     153.000000   153.000000  153.000000  153.000000  153.000000
# mean    36914.287582  1121.281046  565.738562  555.437908    0.564248
# std     57965.886407    94.098944   45.584619   48.851929    0.168729
# min       123.000000   943.000000  482.000000  460.000000    0.210000
# 25%      2047.000000  1055.000000  532.000000  521.000000    0.440000
# 50%     10060.000000  1099.000000  554.000000  546.000000    0.530000
# 75%     49595.000000  1216.000000  614.000000  602.000000    0.750000
# max    272892.000000  1298.000000  644.000000  655.000000    0.870000
#
#        met_neither     erw_met    math_met         year  participation  \
# count   153.000000  153.000000  153.000000   153.000000     153.000000
# mean      0.207516    0.773987    0.582614  2018.000000       0.448693
# std       0.126809    0.127997    0.167193     0.819178       0.370944
# ...

# %% [markdown]
# Summary Statistics when grouping by categories

# %%
df_states.groupby('categories').describe()
# Out:
#            test_takers                                                      \
#                  count          mean           std    min     25%      50%
# categories
# asian            153.0   2919.673203   6600.844750    5.0   188.0    491.0
# black            153.0   4778.941176   7946.954590    1.0   108.0    409.0
# female           153.0  19489.718954  30725.396496   70.0  1120.0   5096.0
# latino           153.0   9293.254902  23407.527467    6.0   131.0   1179.0
# male             153.0  17408.509804  27252.044935   53.0   945.0   4964.0
# multi            153.0   1407.960784   2092.227351    4.0    85.0    434.0
# native           153.0    203.431373    326.910674    0.0     6.0     82.0
# no_race          153.0   1660.274510   3466.698451    2.0    54.0    380.0
# pacific          153.0     84.875817    200.598818    0.0     2.0     15.0
# total            153.0  36914.287582  57965.886407  123.0  2047.0  10060.0
# ...

# %% [markdown]
# Calculating the standard deviation for each category, for all the different columns

# %%
sd_all = {}
sd = {category:{col:calc_std(list(df_states[(df_states['categories'] == category)][col])) for col in df_states.columns if df_states[col].dtype == int or df_states[col].dtype == float} for category in categories}
pd.DataFrame(sd)
# Out:
#                       total        asian         white        latino  \
# test_takers    57965.886407  6600.844750  21387.764470  23407.527467
# total_mean        94.098944    72.278128     81.487658     89.118437
# erw_mean          45.584619    32.427528     40.435511     45.756869
# math_mean         48.851929    41.469827     41.376267     43.679494
# met_both           0.168729     0.109661      0.145048      0.173724
# met_neither        0.126809     0.066216      0.086739      0.159231
# erw_met            0.127997     0.071056      0.090142      0.161672
# math_met           0.167193     0.107104      0.141401      0.170513
# participation      0.370944     0.370944      0.370944      0.370944
# diff_to_ave        0.000000    57.935782     46.483860     39.859541
#
#                   pacific      native        black        multi      no_race  \
# test_takers    200.598818  326.910674  7946.954590  2092.227351  3466.698451
# ...

# %% [markdown]
# Summary of the standard deviation for all of the different categories, the difference, and ratio of the two

# %%
for key in sd.keys():
    print(key,sd[key]['total_mean'],sd[key]['diff_to_ave'],sd[key]['diff_to_ave']/sd[key]['total_mean'])
# Out:
# total 94.09894411261871 0.0 0.0
# asian 72.27812798651401 57.93578216082123 0.8015672759486959
# white 81.48765842808461 46.4838598441028 0.5704404905084646
# latino 89.1184368926175 39.85954142367411 0.447264817623569
# pacific 70.0766445480312 49.29662047365373 0.7034671935507038
# native 73.05227066343829 38.906921425352266 0.5325901723794695
# black 68.07071518287393 41.74004247410018 0.613186483526203
# multi 79.62088881012637 38.14860182133761 0.4791280578682234
# no_race 106.49078890967687 48.71246762293724 0.45743362521479747
# female 86.0746894689877 10.071894978376825 0.11701343380397185
# male 103.61633199088818 11.891508766180772 0.11476481108428435

# %% [markdown]
# Easier to read summary statistics on just the total mean. Helped to give initial perspective on the situation.

# %%
df_states.groupby('categories')['total_mean'].describe()
# Out:
#             count         mean         std     min      25%     50%      75%  \
# categories
# asian       150.0  1220.920000   72.278128  1048.0  1164.00  1214.0  1282.75
# black       142.0   976.316901   68.070715   843.0   922.25   962.0  1033.00
# female      153.0  1108.568627   86.074689   944.0  1048.00  1089.0  1188.00
# latino      150.0  1049.646667   89.118437   897.0   981.25  1043.0  1127.00
# male        153.0  1136.660131  103.616332   934.0  1061.00  1114.0  1249.00
# multi       148.0  1133.324324   79.620889   967.0  1082.75  1116.0  1174.50
# native      105.0   962.219048   73.052271   772.0   906.00   967.0   998.00
# no_race     145.0  1012.427586  106.490789   791.0   929.00  1005.0  1085.00
# pacific      81.0   992.296296   70.076645   819.0   942.00   996.0  1033.00
# total       153.0  1121.281046   94.098944   943.0  1055.00  1099.0  1216.00
# white       153.0  1169.496732   81.487658   946.0  1114.00  1153.0  1249.00
#
#                max
# categories
# ...

# %% [markdown]
# Next few cells are exploring differences in performance based on participation numbers. States with higher participation rates tend to have lower average scores than those states with lower participation rates. This is likely a difference in accessability of the tests in different states, allowing people to take it if on the fence, as opposed to those who are sure they are college bound opting in, and more likely better prepared

# %%
df_all[df_all['categories'] == 'total']['participation'].describe()
# Out:
# count    153.000000
# mean       0.448693
# std        0.370944
# min        0.020000
# 25%        0.040000
# 50%        0.500000
# 75%        0.760000
# max        1.000000
# Name: participation, dtype: float64

# %%
df_all[(df_all['categories'] == 'total') & (df_all['participation'] > 0.99)].sort_values(by=['state','year'])
# Out:
#      categories  test_takers  total_mean  erw_mean  math_mean  met_both  \
# 638       total      58790.0      1025.0     519.0      506.0      0.40
# 1210      total      59494.0      1024.0     518.0      506.0      0.39
# 77        total      43252.0      1041.0     530.0      512.0      0.43
# 649       total      44700.0      1053.0     535.0      519.0      0.44
# 1221      total      44029.0      1046.0     529.0      516.0      0.43
# 88        total      10060.0       996.0     503.0      492.0      0.33
# 660       total      11055.0       998.0     505.0      492.0      0.33
# 1232      total      10990.0       985.0     499.0      486.0      0.31
# 99        total       4801.0       950.0     482.0      468.0      0.28
# 1254      total     190853.0       999.0     516.0      483.0      0.33
# 715       total      20484.0      1001.0     508.0      493.0      0.33
# 1287      total      20749.0       993.0     505.0      488.0      0.32
# ...

# %%
df_all[df_all['participation'] == 1].groupby('categories')['total_mean'].describe()
# Out:
#             count         mean        std     min     25%     50%     75%  \
# categories
# asian        17.0  1161.176471  40.143859  1089.0  1131.0  1162.0  1192.0
# black        17.0   895.352941  16.586671   864.0   885.0   897.0   908.0
# female       17.0  1010.352941  26.186688   944.0  1001.0  1005.0  1025.0
# latino       17.0   932.588235  18.821726   903.0   925.0   934.0   938.0
# male         17.0  1006.000000  24.158332   955.0   994.0  1002.0  1024.0
# multi        17.0  1038.764706  37.300351   980.0  1005.0  1039.0  1071.0
# native       17.0   891.647059  46.900082   797.0   861.0   896.0   906.0
# no_race      17.0   893.176471  48.968402   823.0   859.0   887.0   921.0
# pacific      15.0   923.400000  46.043147   819.0   907.5   928.0   947.0
# total        17.0  1008.117647  24.788814   950.0   996.0  1003.0  1024.0
# white        17.0  1082.882353  58.164511  1033.0  1053.0  1070.0  1088.0
#
#                max
# categories
# asian       1224.0
# ...

# %%
print(df_all[(df_all['participation'] < 0.10) & (df_all['categories'] == 'total')].shape)
df_all[df_all['participation'] < 0.05].groupby('categories')['total_mean'].describe()
# Out:
# (52, 13)
#             count         mean        std     min      25%     50%      75%  \
# categories
# asian        36.0  1308.472222  30.634701  1236.0  1291.75  1312.0  1329.50
# black        31.0  1064.870968  36.337989   990.0  1045.50  1060.0  1087.50
# female       39.0  1228.538462  28.184399  1168.0  1211.50  1228.0  1244.50
# latino       36.0  1163.305556  48.985607  1041.0  1144.75  1172.0  1198.75
# male         39.0  1279.615385  21.325319  1236.0  1262.50  1280.0  1293.00
# multi        34.0  1239.647059  52.771022  1089.0  1213.50  1251.0  1277.75
# native        1.0  1104.000000        NaN  1104.0  1104.00  1104.0  1104.00
# no_race      31.0  1152.161290  56.214528  1047.0  1108.00  1162.0  1190.50
# pacific       0.0          NaN        NaN     NaN      NaN     NaN      NaN
# total        39.0  1252.230769  24.819837  1198.0  1236.50  1252.0  1266.50
# white        39.0  1274.564103  20.851347  1235.0  1259.00  1274.0  1286.50
#
#                max
# categories
# ...

# %% [markdown]
# Look at when minority categories actually perform better than average in a given state, which isn't often. As well as other interesting characteristics seen in plots

# %%
print('latino',df_states[(df_states['categories'] == 'latino') & (df_states['diff_to_ave'] >0)]['state'])
print('pacific',df_states[(df_states['categories'] == 'pacific') & (df_states['diff_to_ave'] >0)]['state'])
# Out:
# latino 213             louisiana
# 1115        west-virginia
# 1247    district-columbia
# 1687        west-virginia
# Name: state, dtype: object
# pacific 170          indiana
# 247    massachusetts
# 434     pennsylvania
# 489            texas
# 742          indiana
# Name: state, dtype: object

# %%
#different interesting categories from histogram

print('>300 white',df_states[(df_states['categories'] == 'white') & (df_states['diff_to_ave'] > 200)]['state'])

print('<0 white',df_states[(df_states['categories'] == 'white') & (df_states['diff_to_ave'] < 0)]['state'])
print('<0 asian',df_states[(df_states['categories'] == 'asian') & (df_states['diff_to_ave'] < 0)]['state'])

temp_df = df_states[df_states['state'] == 'district-columbia']
print('DC',temp_df[['categories','diff_to_ave']])
# Out:
# >300 white 105     district-columbia
# 677     district-columbia
# 1249    district-columbia
# Name: state, dtype: object
# <0 white 1117    west-virginia
# Name: state, dtype: object
# <0 asian 24       alaska
# 299     montana
# 497        utah
# 596      alaska
# 1168     alaska
# 1443    montana
# Name: state, dtype: object
# DC      categories  diff_to_ave
# 99        total          0.0
# 100      native       -112.0
# 101       asian        184.0
# 102       black        -77.0
# 103      latino        -12.0
# 104     pacific          NaN
# 105       white        337.0
# 106       multi        131.0
# 107     no_race       -127.0
# 108      female         -6.0
# 109        male          5.0
# 671       total          0.0
# 672      native       -205.0
# 673       asian        232.0
# 674       black        -75.0
# 675      latino        -24.0
# 676     pacific          NaN
# 677       white        320.0
# 678       multi        120.0
# 679     no_race       -176.0
# ...

# %% [markdown]
# 3.
#
# See a negative correlated trend in the participation and performance.
#
# See that white and Asian groups perform well compared to average, while the rest perform poorly to average.
#
# Mapping to difference from average, greatly reduces varaince, but there is still a lot there compared to splitting on gender which resembles a more natural statistical fluctuation. Shows that not all of the correlation is fixed with this method.
#
# District of Columbia is outlier in white students for high scores, and an outlier for latino/hispanic students being high as well. This would need to be offset by the other ethnicities.
#
# Asians do not do well in Alaska, Utah, or Montana

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#Essentially a version of viridis from ROOT using their definition of kBird. 
#I don't like the color range for viridis
#https://root-forum.cern.ch/t/kbird-is-not-defined/21892
#    Double_t red[9]   = { 0.2082, 0.0592, 0.0780, 0.0232, 0.1802, 0.5301, 0.8186, 0.9956, 0.9764};
#    Double_t green[9] = { 0.1664, 0.3599, 0.5041, 0.6419, 0.7178, 0.7492, 0.7328, 0.7862, 0.9832};
#    Double_t blue[9]  = { 0.5293, 0.8684, 0.8385, 0.7914, 0.6425, 0.4662, 0.3499, 0.1968, 0.0539};
#    Double_t stops[9] = { 0.0000, 0.1250, 0.2500, 0.3750, 0.5000, 0.6250, 0.7500, 0.8750, 1.0000};
cdict2 = {'red':   [(0,0.2082,0.2082),
                    (0.125,0.0592,0.0592),
                    (0.25,0.078,0.078),
                    (0.375,0.0232,0.0232),
                    (0.5,0.1802,0.1802),
                    (0.625,0.5301,0.5301),
                    (0.75,0.8186,0.8186),
                    (0.875,0.9956,0.9956),
                    (1,0.9764,0.9764)],
        'green': [(0,0.1664,0.1664),
                    (0.125,0.3599,0.3599),
                    (0.25,0.5041,0.5041),
                    (0.375,0.6419,0.6419),
                    (0.5,0.7178,0.7178),
                    (0.625,0.7492,0.7492),
                    (0.75,0.7328,0.7328),
                    (0.875,0.7862,0.7862),
                    (1,0.9832,0.9832)],
        'blue':  [(0,0.5293,0.5293),
                    (0.125,0.8684,0.8684),
                    (0.25,0.8385,0.8385),
                    (0.375,0.7914,0.7914),
                    (0.5,0.6425,0.6425),
                    (0.625,0.4662,0.4662),
                    (0.75,0.3499,0.3499),
                    (0.875,0.1968,0.1968),
                    (1,0.0539,0.0539)]
            }
my_cmap2 = matplotlib.colors.LinearSegmentedColormap('my_colormap2',cdict2,256)
colors = cm.rainbow(np.linspace(0, 1, 6))

oneseven = [i for i in range(1,7)]
axis_categories = ['Asian','White','Latino','Hawaiian/\nPacific Islander','Native American','Black']

# %%
#from reusable graph fx
#percentage on axis from https://stackoverflow.com/questions/31357611/format-y-axis-as-percent

def all_corr_heatmap(data, title, size_var = 18, incl_annot = True):
    plt.figure(figsize=(10,6))
    plt.title(title, fontsize = size_var, pad = size_var / 2)
    sns.heatmap(data.corr(), cmap=my_cmap2, vmin = -1, vmax = 1, annot = incl_annot)

def my_scatterplot(data, x_col, y_col, title, x_label, y_label, alpha=1, size_var = 18):
    fig = plt.figure(figsize=(10,6))
    plt.title(title, fontsize = size_var, pad = size_var / 2)
    plt.scatter(x = data[x_col], y = data[y_col]*100, alpha=alpha);

    plt.xlabel(x_label, fontsize = size_var, labelpad = size_var/2)
    plt.xticks(fontsize=size_var/2, rotation=45)

    plt.ylabel(y_label, fontsize = size_var, labelpad = size_var/2)
    plt.axes().yaxis.set_major_formatter(mtick.PercentFormatter())
    plt.yticks(fontsize=size_var/2, rotation=90);

def my_hist(data, x_col, title, x_label, y_label='Frequency', size_var = 18):
    plt.figure(figsize=(6,10));
    sns.displot(x = data[x_col]);

    plt.title(title, fontsize = size_var, pad = size_var / 2);
    
    plt.xlabel(x_label, fontsize = size_var, labelpad = size_var/2)
    plt.xticks(fontsize=size_var/2, rotation=45)
    
    plt.ylabel(y_label, fontsize = size_var, labelpad = size_var/2)
    plt.yticks(fontsize=size_var/2, rotation=90);

# %% [markdown]
# All entries are 0 for diff_to_ave for the total category (total_ave - total_ave = 0), so cant calculate correlation. Many of the variables will inherently have strong correlation and anti-correlation. Some of these are reduced in the second heatmap. For example, math, erw, and total mean will inherently be related to each other, so the individual components are dropped for the second one.
#
# No strong correlation for year to student performance, if anything slightly worse probably due to higher participation. "test_takers" follows participation correlation, just not as strong because state size muddles it.

# %%
all_corr_heatmap(
    data = df_states[df_states['categories'] == 'total'],
    title = 'All correlations for different test score statistics for entire popultation'
)

# %%
all_corr_heatmap(
    data = df_states[df_states['categories'] == 'total'].drop(
        columns=['erw_mean','math_mean','erw_met','math_met','diff_to_ave']),
    title = 'All correlations for different test score statistics for entire popultation'
)

# %%
#boxplot with all available categories, for the problem statement some were ommitted
#in later iterations to make plot more concise
plt.figure(figsize=(12,8));
sns.boxplot(data=df_states,y='categories',x='total_mean');
plt.axes().set_xlabel('Mean Total Score');
plt.axes().set_title('Average Scores for Different Reports Grouped by Ethnicity and Gender',fontsize = 18)
# Out:
# <ipython-input-42-c9aa0fdca65c>:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set_xlabel('Mean Total Score');
# <ipython-input-42-c9aa0fdca65c>:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set_title('Average Scores for Different Reports Grouped by Ethnicity and Gender',fontsize = 18)
# Text(0.5, 1.0, 'Average Scores for Different Reports Grouped by Ethnicity and Gender')

# %% [markdown]
# All categories, have fairly wide spread, which will later be reduced when corrected by state. The state correction greatly reduces uncertainty as seen before, and a larger gap between ethnicities can be seen. The mean total tracks with meeting both benchmarks as expected, but one misleading thing most people would probably overlook is what the scale translates to for a score and whether or not they meet benchmarks. Comparing latinos to whites, a little more than a 100 point difference in the average total score (with a max score of 1600) translates to ~30% to the group median meeting both benchmarks, nearly doubling the overall value. These are standardized tests and fall on a bell curve, so a >100 point increase is nearing a standard devation difference for the actual population.

# %%
#https://www.geeksforgeeks.org/box-plot-in-python-using-matplotlib/     boxplot tutorial
#Reordered by Median value
df_bycat_total = []
for i in range(1,7):
    df_bycat_total.append(df_states[df_states['categories'] == categories[i]].dropna()['total_mean'])

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)

bp = ax.boxplot(df_bycat_total, patch_artist = True,vert=0)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
ax.set_yticklabels(axis_categories)
ax.set_title('Average Scores for Varying Ethnicities Across States',fontsize = 18)
ax.set_ylabel('Ethnicity',fontsize = 12)
ax.set_xlabel('Average Total Score',fontsize = 12)
for median in bp['medians']:
    median.set(color ='black',
               linewidth = 2)


plt.show(bp)

# %%
#https://www.geeksforgeeks.org/box-plot-in-python-using-matplotlib/     boxplot tutorial
#Same histogram, now using the difference to the average. 
df_bycat_diff = []
for i in range(1,7):
    df_bycat_diff.append(df_states[df_states['categories'] == categories[i]].dropna()['diff_to_ave'])

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)

bp = ax.boxplot(df_bycat_diff, patch_artist = True,vert=0)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
ax.set_yticklabels(axis_categories)
ax.set_title('Difference to Average Scores for Varying Ethnicities Across States',fontsize = 18)
ax.set_ylabel('Ethnicity',fontsize = 12)
ax.set_xlabel('Difference to Average Total Score',fontsize = 12)

for median in bp['medians']:
    median.set(color ='black',
               linewidth = 2)
plt.grid()

plt.show(bp)

# %%
#Making the box plot from above into histograms, as more information to the
#tails of the distribution as well as shape easier to be seen
#Outliers in white: Washington, DC

fig = plt.figure(figsize=(8,12))
hbins = [20*i-280 for i in range(32)]

ax1 = plt.subplot(6, 1, 1)
ax1.set_title('Black Student Score to State Average')
ax1.set_xlabel('Group Average to Total Average')
ax1.set_ylabel('Instances')
ax1.hist(df_bycat_diff[5],color=colors[5],bins=hbins)
ax1.axvline(x = np.mean(df_bycat_diff[5]), color = 'black')
ax1.axvline(x = 0, color = 'black', linestyle='dashed')

# plt.subplot(3, 1, 2) means we have 3 rows, 1 column, and are referencing plot 2.
ax2 = plt.subplot(6, 1, 2, sharex=ax1)
ax2.set_title('Native American Student Score to State Average')
ax2.set_xlabel('Group Average to Total Average')
ax2.set_ylabel('Instances')
ax2.hist(df_bycat_diff[4],color=colors[4],bins=hbins)
ax2.axvline(x = np.mean(df_bycat_diff[4]), color = 'black')
ax2.axvline(x = 0, color = 'black', linestyle='dashed')

# plt.subplot(3, 1, 3) means we have 3 rows, 1 column, and are referencing plot 3.
ax3 = plt.subplot(6, 1, 3, sharex=ax2)
ax3.set_title('Hawaiian/Pacific Islander Student Score to State Average')
ax3.set_xlabel('Group Average to Total Average')
ax3.set_ylabel('Instances')
ax3.hist(df_bycat_diff[3],color=colors[3],bins=hbins)
ax3.axvline(x = np.mean(df_bycat_diff[3]), color = 'black')
ax3.axvline(x = 0, color = 'black', linestyle='dashed')

ax4 = plt.subplot(6, 1, 4, sharex=ax3)
ax4.set_title('Latino Student Score to State Average')
ax4.set_xlabel('Group Average to Total Average')
ax4.set_ylabel('Instances')
ax4.hist(df_bycat_diff[2],color=colors[2],bins=hbins)
ax4.axvline(x = np.mean(df_bycat_diff[2]), color = 'black')
ax4.axvline(x = 0, color = 'black', linestyle='dashed')

ax5 = plt.subplot(6, 1, 5, sharex=ax3)
ax5.set_title('White Student Score to State Average')
ax5.set_xlabel('Group Average to Total Average')
ax5.set_ylabel('Instances')
ax5.hist(df_bycat_diff[1],color=colors[1],bins=hbins)
ax5.axvline(x = np.mean(df_bycat_diff[1]), color = 'black')
ax5.axvline(x = 0, color = 'black', linestyle='dashed')


ax6 = plt.subplot(6, 1, 6, sharex=ax3)
ax6.set_title('Asian Student Score to State Average')
ax6.set_xlabel('Group Average to Total Average')
ax6.set_ylabel('Instances')
ax6.hist(df_bycat_diff[0],color=colors[0],bins=hbins)
ax6.axvline(x = np.mean(df_bycat_diff[0]), color = 'black')
ax6.axvline(x = 0, color = 'black', linestyle='dashed')

plt.tight_layout(1);
# Out:
# <ipython-input-45-6f86717351ff>:59: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(1);

# %%
#percentage from https://stackoverflow.com/questions/31357611/format-y-axis-as-percent
#Boxplots showing percentage making both benchmarks.
df_bycat_met = []
for i in range(1,7):
    df_bycat_met.append(df_states[df_states['categories'] == categories[i]].dropna()['met_both']*100)

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)

bp = ax.boxplot(df_bycat_met, patch_artist = True,vert=0)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
ax.set_yticklabels(axis_categories)
for median in bp['medians']:
    median.set(color ='black',
               linewidth = 2)
ax.set_title('Percent of Test Takers Meeting Both Subject Benchmarks', fontsize = 18)
ax.set_xlabel('Percent Meeting Both Benchmarks',fontsize = 14)
ax.set_ylabel('Ethnicity',fontsize = 14)
ax.axvline(x = 50, color = 'black', linestyle='dashed')
ax.xaxis.set_major_formatter(mtick.PercentFormatter())

plt.show(bp)

# %% [markdown]
# The negative correlation seen repeatedly for participation and total mean score is seen here for both All combined, and individual ethnic categories. Black is shown individually to compare to the shape of the total since the all plot is kind of overwhelming. Different ethnicities show the same trend, but variation when splitting states also varies based on race. This reiterates the point that there are race factors on a state to state basis that cannot be removed just by subtracting the average, but it is helped.

# %%
my_scatterplot( data = df_states[df_states['categories'] == 'total'],
    x_col='total_mean',
    y_col='participation',
    title = 'Mean Scores by State Participation for All Students',
    x_label = 'Mean Total Score',
    y_label = 'State Participation'
)
my_scatterplot( data = df_states[df_states['categories'] == 'black'],
    x_col='total_mean',
    y_col='participation',
    title = 'Mean Scores by State Participation for Black/African American Students',
    x_label = 'Mean Total Score',
    y_label = 'State Participation'
)
# Out:
# <ipython-input-39-6d3d48e33e75>:16: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().yaxis.set_major_formatter(mtick.PercentFormatter())

# %%
#coloring from here https://stackoverflow.com/questions/12236566/setting-different-color-for-each-series-in-scatter-plot-on-matplotlib
fig = plt.figure(figsize=(12,8))

for i in range(1,7):
    plt.scatter(df_states[df_states['categories'] == categories[i]]['total_mean'],df_states[df_states['categories'] == categories[i]]['participation']*100,color=colors[i-1])

title = 'Mean Scores By State Pariticpation By Ethnicity'
size_var = 18
plt.title(title, fontsize = size_var, pad = size_var / 2)

plt.xlabel('Mean Total Score', fontsize = size_var, labelpad = size_var/2)
plt.xticks(fontsize=size_var/2, rotation=45)

plt.ylabel('State Participation', fontsize = size_var, labelpad = size_var/2)
plt.axes().yaxis.set_major_formatter(mtick.PercentFormatter())
plt.yticks(fontsize=12, rotation=90);
# Out:
# <ipython-input-48-c5602258fb4f>:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().yaxis.set_major_formatter(mtick.PercentFormatter())

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# Results from the SAT show a strong correlation between ethnicity and SAT performance, and therefore at some level there is a fundamental bias. However, correlation does not prove causation
#
# Although the bias is clear, more studies would need to be performed to better understand the cause of these differences.
#  - Potential causes could stem from socioeconomic factors, cultural importance on scholastic performance and test preparation, and difference in public school quality based on location.
#  - Difference in SAT scores may not be indicative of an actual difference in intelligence
#
# Recommend placing less emphasis on SAT results for college admission until more research can be done on the cause of discrepancies

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
